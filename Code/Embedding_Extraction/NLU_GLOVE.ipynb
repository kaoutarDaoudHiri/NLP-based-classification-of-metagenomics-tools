# %% [markdown]
# # 1. Install Java and NLU

# %%
import os
import pandas as pd
import numpy as np

! apt-get update -qq > /dev/null   
# Install jav
! apt-get install -y openjdk-8-jdk-headless -qq > /dev/null
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["PATH"] = os.environ["JAVA_HOME"] + "/bin:" + os.environ["PATH"]
! pip install nlu pyspark==3.3 > /dev/null

# %% [markdown]
# # 2. Load data

# %%
from google.colab import files
df=pd.read_csv("./AbstractsMethods-kwlg-Parsed.csv", sep=',')
#df=pd.read_csv("./Methods-Parsed.csv", sep=',')
df=df.rename(columns={'Content_Parsed': 'text'})

# %%
import nlu
pipe = nlu.load('glove ')
# Out:
# glove_100d download started this may take some time.
# Approximate size to download 145.3 MB
# [OK!]
# sentence_detector_dl download started this may take some time.
# Approximate size to download 354.6 KB
# [OK!]

# %% [markdown]
# #  3. Load Model and Embed sample string

# %%
import numpy as np
embeddings = []
all_embeddings = []
sentence_embedding = np.empty(100, dtype=object)

c=0
for txt in df['text']:
  print("*****************item ",c)
  print ("----------- step1:")
  embedding = pipe.predict([txt])
  print ("----------- step2:")
  embedding = embedding.reset_index(drop=True)
  print ("----------- step3:")
  flatkeys=[element for sublist in embedding['token'].tolist() for element in sublist]
  flatvalues=[element for sublist in embedding['word_embedding_glove'].tolist() for element in sublist]
  embedding = dict(zip(flatkeys, flatvalues))
  print ("----------- step4:")
  embeddings.append(embedding)
  c=c+1
# Out:
# *****************item  0
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  1
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  2
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  3
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  4
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  5
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  6
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  7
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  8
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  9
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  10
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  11
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  12
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  13
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  14
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  15
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  16
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  17
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  18
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  19
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  20
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  21
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  22
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  23
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  24
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  25
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  26
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  27
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  28
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  29
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  30
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  31
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  32
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  33
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  34
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  35
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  36
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  37
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  38
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  39
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  40
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  41
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  42
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  43
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  44
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  45
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  46
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  47
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  48
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  49
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  50
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  51
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  52
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  53
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  54
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  55
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  56
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  57
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  58
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  59
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  60
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  61
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  62
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  63
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  64
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  65
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  66
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  67
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  68
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  69
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  70
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  71
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  72
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  73
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  74
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  75
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  76
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  77
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  78
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  79
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  80
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  81
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  82
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  83
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  84
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  85
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  86
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  87
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  88
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  89
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  90
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  91
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  92
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  93
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  94
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  95
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  96
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  97
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  98
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  99
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  100
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  101
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  102
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  103
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  104
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  105
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  106
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  107
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  108
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  109
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  110
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  111
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  112
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  113
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  114
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  115
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  116
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  117
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  118
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  119
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  120
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  121
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  122
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  123
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  124
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  125
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  126
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  127
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  128
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  129
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  130
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  131
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  132
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  133
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  134
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  135
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  136
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  137
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  138
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  139
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  140
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  141
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  142
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  143
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  144
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  145
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  146
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  147
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  148
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  149
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  150
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  151
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  152
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  153
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  154
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  155
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  156
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  157
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  158
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  159
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  160
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  161
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  162
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  163
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  164
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  165
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  166
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  167
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  168
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  169
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  170
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  171
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  172
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  173
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  174
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  175
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  176
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  177
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  178
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  179
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  180
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  181
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  182
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  183
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  184
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  185
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  186
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  187
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  188
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  189
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  190
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  191
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  192
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  193
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  194
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  195
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  196
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  197
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  198
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  199
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  200
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  201
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  202
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  203
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  204
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  205
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  206
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  207
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  208
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  209
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  210
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  211
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  212
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  213
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  214
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  215
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  216
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  217
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  218
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  219
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  220
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  221
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  222
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:
# *****************item  223
# ----------- step1:
# ----------- step2:
# ----------- step3:
# ----------- step4:

# %%
for l in range(len(embeddings)):
  for v in embeddings[l].values():
    sentence_embedding=np.vstack((sentence_embedding, v))
  sentence_embedding = np.delete(sentence_embedding, obj=0, axis=0)
  sentence_embedding = (np.mean(sentence_embedding, axis=0)).tolist()
  all_embeddings.append(sentence_embedding)

all_embeddings = np.array(all_embeddings)
all_embeddings = pd.DataFrame(all_embeddings)

all_embeddings.insert(loc=0, column='text', value=df['text'])

# %%
all_embeddings.to_csv('Methods-kwlg-GLOVE.csv') 
files.download("Methods-kwlg-GLOVE.csv")
